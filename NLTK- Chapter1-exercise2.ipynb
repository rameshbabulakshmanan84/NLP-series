# %%
#This deasl with exercises from chapter 1 of NLTK dealing with belo functionaltie ssyuch as ordering elemnts in terms of freuency,
#average size of the words and string filter

# %%
#import the libraries
import nltk
import pandas as pd
import numpy as np

# %%
nltk.download('treebank')
nltk.download('genesis')
#import stopwords package
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\BrindhaM\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\BrindhaM\AppData\Roaming\nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\BrindhaM\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
#Find all the four-letter words in the Chat Corpus (text5). 
text5

#With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.
# Out:
# <Text: Chat Corpus>

# %%
#describe freq dist
Fdist=FreqDist(text5)

# %%
Fdist
# Out:
# FreqDist({'now': 79,
#           'im': 128,
#           'left': 17,
#           'with': 152,
#           'this': 86,
#           'gay': 30,
#           'name': 27,
#           ':P': 15,
#           'PART': 1016,
#           'hey': 264,
#           'everyone': 63,
#           'ah': 8,
#           'well': 81,
#           'NICK': 24,
#           ':': 96,
#           'U7': 119,
#           'is': 372,
#           'a': 568,
#           '.': 1268,
#           'ACTION': 346,
#           'gives': 6,
#           'U121': 36,
#           'golf': 2,
#           'clap': 3,
#           ':)': 101,
#           'JOIN': 1021,
#           'hi': 546,
#           'U59': 12,
#           '26': 10,
#           '/': 133,
#           'm': 81,
#           'ky': 2,
#           'women': 7,
#           'that': 274,
#           'are': 178,
#           'nice': 52,
#           'please': 21,
#           'pm': 108,
#           'me': 415,
#           'there': 120,
#           'ya': 100,
#           'go': 73,
# ...

# %%
#filter the 4 letters words from the freqdistribution table along with frequency of occurance
words=[(w,Fdist[w]) for w in Fdist if len(w)==4]

# %%
#Words is list of tuples
words
# Out:
# [('left', 17),
#  ('with', 152),
#  ('this', 86),
#  ('name', 27),
#  ('PART', 1016),
#  ('well', 81),
#  ('NICK', 24),
#  ('U121', 36),
#  ('golf', 2),
#  ('clap', 3),
#  ('JOIN', 1021),
#  ('that', 274),
#  ('nice', 52),
#  ('fuck', 15),
#  ('your', 137),
#  ('dont', 75),
#  ('even', 35),
#  ('know', 103),
#  ('what', 183),
#  ('chat', 142),
#  ('drew', 2),
#  ('cast', 2),
#  ('sexy', 23),
#  ('U115', 36),
#  ('girl', 43),
#  ('legs', 5),
#  ('hope', 12),
#  ('draw', 1),
#  ('head', 12),
#  ('good', 130),
#  ('take', 37),
#  ('have', 164),
#  ('docs', 1),
#  ('Slip', 1),
#  ('away', 26),
#  ('Fade', 1),
#  ('Days', 2),
#  ('feel', 19),
#  ('back', 78),
#  ('U129', 6),
#  ('fast', 7),
#  ('U116', 6),
#  ('bowl', 1),
#  ('bong', 1),
#  ('glad', 4),
#  ('hard', 10),
#  ('from', 92),
#  ('here', 181),
#  ('very', 19),
#  ('fire', 5),
#  ('itch', 3),
#  ('U133', 4),
#  ('ogan', 1),
#  ('male', 12),
#  ('show', 10),
#  ('will', 40),
#  ('talk', 56),
#  ('haha', 44),
#  ('opps', 2),
# ...

# %%
#Demonstartion of accessing the individual items in a tuple
w1=words[0]
w1
# Out:
# ('left', 17)

# %%
#Sort the  four letter word with second index (frequency of occurance)
sorted(words,key=lambda words:words[1] )
# Out:
# [('draw', 1),
#  ('docs', 1),
#  ('Slip', 1),
#  ('Fade', 1),
#  ('bowl', 1),
#  ('bong', 1),
#  ('ogan', 1),
#  ('cams', 1),
#  ('gooo', 1),
#  ('yeee', 1),
#  ('ahah', 1),
#  ('jeep', 1),
#  ('Deep', 1),
#  ('Show', 1),
#  ('Turn', 1),
#  ('Hand', 1),
#  ('VBox', 1),
#  ('ELSE', 1),
#  ('serg', 1),
#  ('bein', 1),
#  ('whys', 1),
#  ('tape', 1),
#  ('sexs', 1),
#  ('form', 1),
#  ('HUGE', 1),
#  ('nads', 1),
#  ('owww', 1),
#  ('gags', 1),
#  ('Meep', 1),
#  ('LAst', 1),
#  ("pm's", 1),
#  ('1.99', 1),
#  ('lool', 1),
#  ('kina', 1),
#  ('sext', 1),
#  ('lazy', 1),
#  ('calm', 1),
#  ('arms', 1),
#  ('smax', 1),
#  ('VVil', 1),
#  ('este', 1),
#  ('chik', 1),
#  ('Boyz', 1),
#  ('coat', 1),
#  ('Eyes', 1),
#  ('Dawn', 1),
#  ('LIVE', 1),
#  ('mauh', 1),
#  ('ques', 1),
#  ('4.20', 1),
#  ('gosh', 1),
#  ('ruff', 1),
#  ('mame', 1),
#  ('nada', 1),
#  ('push', 1),
#  ('prob', 1),
#  ('wild', 1),
#  ('whew', 1),
#  ('dark', 1),
#  ('waht', 1),
#  ('test', 1),
#  ('boot', 1),
# ...

# %%
text6
# Out:
# <Text: Monty Python and the Holy Grail>

# %%
#loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.
words=[w for w in text6 if w.isupper()]

# %%
#print the uppercase words 1 in a line
words
# Out:
# ['SCENE',
#  'KING',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'I',
#  'SOLDIER',
#  'ARTHUR',
#  'I',
#  'I',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'A',
#  'ARTHUR',
#  'SOLDIER',
#  'A',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'I',
#  'ARTHUR',
#  'I',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'I',
#  'ARTHUR',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SCENE',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'CART',
#  'MASTER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CUSTOMER',
#  'CART',
#  'MASTER',
#  'I',
#  'DEAD',
# ...

# %%
#Write expressions for finding all words in text6 that meet the conditions listed below.
#The result should be in the form of a list of words: ['word1', 'word2', ...].
text6
# Out:
# <Text: Monty Python and the Holy Grail>

# %%
#Ending in ise
words=[w for w in text6 if w.endswith('ise')]

# %%
#print the wrods ending in ise
words
# Out:
# ['wise',
#  'wise',
#  'apologise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'noise',
#  'surprise']

# %%
#Containing the letter z
print([w for w in text6 if 'z' in w])
# Out:
# ['zone', 'amazes', 'Fetchez', 'Fetchez', 'zoop', 'zoo', 'zhiv', 'frozen', 'zoosh']

# %%
#Having all lowercase letters except for an initial capital
print([w for w in text6 if w.istitle()])
# Out:
# ['Whoa', 'Halt', 'Who', 'It', 'I', 'Arthur', 'Uther', 'Pendragon', 'Camelot', 'King', 'Britons', 'Saxons', 'England', 'Pull', 'I', 'Patsy', 'We', 'Camelot', 'I', 'What', 'Ridden', 'Yes', 'You', 'What', 'You', 'So', 'We', 'Mercea', 'Where', 'We', 'Found', 'In', 'Mercea', 'The', 'What', 'Well', 'The', 'Are', 'Not', 'They', 'What', 'A', 'It', 'It', 'It', 'A', 'Well', 'Will', 'Arthur', 'Court', 'Camelot', 'Listen', 'In', 'Please', 'Am', 'I', 'I', 'It', 'African', 'Oh', 'African', 'European', 'That', 'Oh', 'I', 'Will', 'Camelot', 'But', 'African', 'Oh', 'So', 'Wait', 'Supposing', 'No', 'Well', 'They', 'What', 'Well', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Ninepence', 'Bring', 'Bring', 'Bring', 'Bring', 'Here', 'Ninepence', 'I', 'What', 'Nothing', 'Here', 'I', 'Ere', 'He', 'Yes', 'I', 'He', 'Well', 'He', 'I', 'No', 'You', 'Oh', 'I', 'It', 'I', 'Oh', 'I', 'I', 'Well', 'I', 'Well', 'He', 'No', 'I', 'Robinson', 'They', 'Well', 'Thursday', 'I', 'I', 'You', 'Lo
# ...

# %%
#average word length of a text 1
#find the count of words
count=len(text1)
print(count)
# Out:
# 260819

# %%
#sum the size of each word length
size_w=[len(w) for w in text1]
#sum the contents in size_w
sum1=sum(size_w)
print(sum1)
# Out:
# 999044

# %%
#calclate the average length
average_length = sum1/count
#print -> Aerage word size is 3 .83 chars length
print(average_length)
# Out:
# 3.830411128023649
