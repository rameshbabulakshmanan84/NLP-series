# %%
#Import the nltk toolkit ->Natural language tool kit
import nltk
#imort the books packagae
nltk.download('treebank')
nltk.download('genesis')
#import stopwords package
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\BrindhaM\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
#imort the list of books
from nltk.book import *

# %%
text4
# Out:
# <Text: Inaugural Address Corpus>

# %%
#A concordance view shows us every occurrence of a given word, together with some context
text4.concordance("monstrous")
# Out:
# no matches

# %%
#What other words appear in a similar range of contexts? We can find out by appending the term similar to the name of the text in question, then inserting the relevant word in parentheses:
text4.similar('monstrous')
# Out:
# No matches

# %%
 term common_contexts allows us to examine just the contexts that are shared by two or more words,#
text1.common_contexts(['monstrous','very'])
# Out:
# No common contexts were found

# %%
#Compuet the length of text
len(text1)
# Out:
# 260819

# %%
#print the distinct words for text1  
set(text1)
# Out:
# {'Pedestrians',
#  'persecutor',
#  'WHALES',
#  'puffed',
#  'grip',
#  'raised',
#  'such',
#  'piloted',
#  'equipped',
#  'proceeding',
#  'forswearing',
#  'small',
#  'robed',
#  'wet',
#  'shoreless',
#  'drown',
#  'wrench',
#  'bidden',
#  'protecting',
#  'moon',
#  'undashed',
#  'absent',
#  'intrantem',
#  'populous',
#  'leagues',
#  'fan',
#  'soliloquizes',
#  'unmindful',
#  '1671',
#  'interferes',
#  'successfully',
#  'strongly',
#  'immediately',
#  'Polar',
#  'fatherless',
#  'End',
#  'Pantheistic',
#  'zone',
#  'Japans',
#  'qualities',
#  'dimly',
#  'parading',
#  'yawing',
#  'Traitors',
#  'choking',
#  'exact',
#  'arid',
#  'snuff',
#  'Isolatoes',
#  'leaking',
#  'Sphinx',
#  'err',
#  'mumbling',
#  'NEVER',
#  'prophetic',
#  'apportioned',
#  'sickle',
#  'knife',
#  'cavern',
#  'uttermost',
#  'half',
#  'effort',
#  'worthy',
#  'presence',
#  'shadows',
#  'verdant',
#  'jewels',
#  'quiescence',
#  'Wonder',
#  'tranquilly',
# ...

# %%
#get the dstnict words count using length
len(set(text1))

# %%
#The percenage of contribution on an average by each of the words
len(set(text1))/len(text1)
# Out:
# 0.07406285585022564

# %%
#Count the occuance of "smote" in text3
text3.count("smote")
# Out:
# 5

# %%
#%percentage occurance of 'a' in text1
text3.count("a")/len(text1) * 100
# Out:
# 0.13112541647656037

# %%
#list operations

# %%
sent1=['call','me','ist']

# %%
sent1
# Out:
# ['call', 'me', 'ist']

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
#Concatenation of list
sent3=sent1+sent2

# %%
sent3
# Out:
# ['call',
#  'me',
#  'ist',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
#Count the number of times the word 'heaven' occurs
text1.count('heaven')
# Out:
# 40

# %%
#find the index of the word'awaken'
text1.index('awaken')
# Out:
# 87935

# %%
#String operations

# %%
name='Monty'

# %%
name[0]
# Out:
# 'M'

# %%
name*2
# Out:
# 'MontyMonty'

# %%
sent1*2
# Out:
# ['call', 'me', 'ist', 'call', 'me', 'ist']

# %%
#Frequency distribution of the words in the text
fdist1 = FreqDist(text1)

# %%
fdist1
# Out:
# FreqDist({'[': 3,
#           'Moby': 84,
#           'Dick': 84,
#           'by': 1137,
#           'Herman': 1,
#           'Melville': 1,
#           '1851': 3,
#           ']': 1,
#           'ETYMOLOGY': 1,
#           '.': 6862,
#           '(': 210,
#           'Supplied': 2,
#           'a': 4569,
#           'Late': 1,
#           'Consumptive': 1,
#           'Usher': 2,
#           'to': 4542,
#           'Grammar': 2,
#           'School': 1,
#           ')': 78,
#           'The': 612,
#           'pale': 18,
#           '--': 1070,
#           'threadbare': 1,
#           'in': 3916,
#           'coat': 28,
#           ',': 18713,
#           'heart': 90,
#           'body': 110,
#           'and': 6024,
#           'brain': 37,
#           ';': 4072,
#           'I': 2124,
#           'see': 253,
#           'him': 1058,
#           'now': 646,
#           'He': 230,
#           'was': 1632,
#           'ever': 203,
#           'dusting': 2,
#           'his': 2459,
# ...

# %%
# lst the words by their Most common occurances 
fdist1.most_common()
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %%
#find the longwords in text1 (length :15)
V=set(text1)

# %%
#identfy the word length greater than 15
lon_words=[W for W in V if len(W)>15]

# %%
#Sort the words in ascending order
sorted(lon_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
#Freqdistribution of text5
fdist=FreqDist(text5)

# %%
#identify the lenth greate than 7 and frequency distribution of that word greater than 7
sorted(W for W in set(text5) if len(W)>7 and fdist[W]>7 )
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
print(fdist)
# Out:
# <FreqDist with 6066 samples and 45010 outcomes>

# %%
#A collocation is a sequence of words that occur together unusually often.
#ex: redwine

# %%
#we start off by extracting from a text a list of word pairs, also known as bigrams. This is easily accomplished with the function bigrams():list
list(bigrams(['more','is','said','than','done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
#rint the collocation list
text1.collocation_list()
# Out:
# ['Sperm Whale',
#  'Moby Dick',
#  'White Whale',
#  'old man',
#  'Captain Ahab',
#  'sperm whale',
#  'Right Whale',
#  'Captain Peleg',
#  'New Bedford',
#  'Cape Horn',
#  'cried Ahab',
#  'years ago',
#  'lower jaw',
#  'never mind',
#  'Father Mapple',
#  'cried Stubb',
#  'chief mate',
#  'white whale',
#  'ivory leg',
#  'one hand']

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
#Freuencydistributon of words 
fdist=FreqDist(len(w) for w in text1)

# %%
#Print the frequency distribution
fdist
# Out:
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
#Find the sorted list
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
#sorted the details with 'gnt' in the text4
sorted(term for term in set(text4) if 'gnt' in term)
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
#selected the words fllowing ttlecase
sorted(term for term in set(text6) if term.istitle())
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
#
sorted(item for item in set(sent7) if item.isdigit())
# Out:
# ['29', '61']

# %%
sorted(w for w in set(text7) if '-' in w and 'index' in w)
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
sorted(w for w in set(text7) if w.islower())
# Out:
# ["'30s",
#  "'40s",
#  "'50s",
#  "'80s",
#  "'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  '10-day',
#  '10-lap',
#  '10-year',
#  '100-megabyte',
#  '100-share',
#  '10th',
#  '11-month-old',
#  '11th',
#  '12-member',
#  '12-point',
#  '12-year',
#  '120-a-share',
#  '14-hour',
#  '15-day',
#  '150-point',
#  '17-year-old',
#  '18-a-share',
#  '18-year-old',
#  '19-month-old',
#  '190-point',
#  '1920s',
#  '1940s',
#  '1950s',
#  '1960s',
#  '1970s',
#  '1980s',
#  '1990s',
#  '1\\/10th',
#  '1st',
#  '2,050-passenger',
#  '20-point',
#  '20-stock',
#  '20s',
#  '21-month',
#  '237-seat',
#  '238,000-circulation',
#  '240-page',
#  '25-year-old',
#  '27-year',
#  '29year',
#  '30-day',
#  '30-minute',
#  '30-point',
#  '30-share',
#  '30-year',
#  '300-a-share',
#  '300-day',
#  '30s',
#  '31-year-old',
#  '36-day',
#  '36-minute',
#  '36-store',
#  '37-a-share',
#  '37-year-old',
#  '40-megabyte',
#  '40-year-old',
#  '42-year',
#  '43-year-old',
#  '45-a-share',
# ...

# %%
[w.upper() for w in text1]
# Out:
# ['[',
#  'MOBY',
#  'DICK',
#  'BY',
#  'HERMAN',
#  'MELVILLE',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'SUPPLIED',
#  'BY',
#  'A',
#  'LATE',
#  'CONSUMPTIVE',
#  'USHER',
#  'TO',
#  'A',
#  'GRAMMAR',
#  'SCHOOL',
#  ')',
#  'THE',
#  'PALE',
#  'USHER',
#  '--',
#  'THREADBARE',
#  'IN',
#  'COAT',
#  ',',
#  'HEART',
#  ',',
#  'BODY',
#  ',',
#  'AND',
#  'BRAIN',
#  ';',
#  'I',
#  'SEE',
#  'HIM',
#  'NOW',
#  '.',
#  'HE',
#  'WAS',
#  'EVER',
#  'DUSTING',
#  'HIS',
#  'OLD',
#  'LEXICONS',
#  'AND',
#  'GRAMMARS',
#  ',',
#  'WITH',
#  'A',
#  'QUEER',
#  'HANDKERCHIEF',
#  ',',
#  'MOCKINGLY',
#  'EMBELLISHED',
#  'WITH',
#  'ALL',
#  'THE',
#  'GAY',
#  'FLAGS',
#  'OF',
#  'ALL',
#  'THE',
#  'KNOWN',
#  'NATIONS',
#  'OF',
#  'THE',
#  'WORLD',
#  '.',
#  'HE',
#  'LOVED',
#  'TO',
#  'DUST',
#  'HIS',
#  'OLD',
#  'GRAMMARS',
#  ';',
#  'IT',
#  'SOMEHOW',
#  'MILDLY',
#  'REMINDED',
#  'HIM',
#  'OF',
#  'HIS',
#  'MORTALITY',
#  '.',
#  '"',
# ...

# %%
#gradually caluclate the length based on filtering
len(text1)
# Out:
# 260819

# %%
len(set(text1))
# Out:
# 19317

# %%
len(set(w.lower() for w in text1 ))
# Out:
# 17231

# %%
#eliminate numbers and punctuation from the vocabulary count by filtering out any non-alphabetic items:
len(set(W.lower() for W in text1 if W.isalpha()))
# Out:
# 16948
